# %%
import tensorflow as tf
import tensorflow_hub as hub
import glob
import PIL
from IPython.display import Image

# %%
# This function:
# Loads the PNG image at the given path
# Decodes the PNG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_png(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
  return img

# %%
module_handle = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4" 
module = hub.load(module_handle)
# Extract image features of the target image
target_img_path = '/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190905073849.png'
target_img = load_img(target_img_path)
target_img = module(target_img)
print("-----------------------------------------------------------------------------------------")
print("Extracing image features of the target image is done")

# Extract image features of the input image
i = 0
input_count = 0
input_imgs = []
for filename in glob.glob('/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/*.png'):
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)
    input_imgs.append([features, filename])
    input_count = input_count + 1
print("-----------------------------------------------------------------------------------------")
print("Extracting image features of the %d input images is done" %(input_count))
# Out:
# -----------------------------------------------------------------------------------------
# Extracing image features of the target image is done
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190905073849.png
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190919125354.png
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190905125532.png
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190905212702.png
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190906065539.png
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190906114940.png
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190906191003.png
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190907075641.png
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190907123305.png
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190907185640.png
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190908080513.png
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190908125139.png
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190908201045.png
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190909062055.png
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190909115643.png
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190910060814.png
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190910120657.png
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190911064540.png
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190911114349.png
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190911214117.png
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190912061624.png
# -----------------------------------------------------------------------------------------
# Image count                     :22
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190912132804.png
# -----------------------------------------------------------------------------------------
# Image count                     :23
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190912201426.png
# -----------------------------------------------------------------------------------------
# Image count                     :24
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190913091406.png
# -----------------------------------------------------------------------------------------
# Image count                     :25
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190913153315.png
# -----------------------------------------------------------------------------------------
# Image count                     :26
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190913202119.png
# -----------------------------------------------------------------------------------------
# Image count                     :27
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190914080339.png
# -----------------------------------------------------------------------------------------
# Image count                     :28
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190914122116.png
# -----------------------------------------------------------------------------------------
# Image count                     :29
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190914225402.png
# -----------------------------------------------------------------------------------------
# Image count                     :30
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190915084009.png
# -----------------------------------------------------------------------------------------
# Image count                     :31
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190915134625.png
# -----------------------------------------------------------------------------------------
# Image count                     :32
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190915183502.png
# -----------------------------------------------------------------------------------------
# Image count                     :33
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190916070322.png
# -----------------------------------------------------------------------------------------
# Image count                     :34
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190916115418.png
# -----------------------------------------------------------------------------------------
# Image count                     :35
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190916184955.png
# -----------------------------------------------------------------------------------------
# Image count                     :36
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190917063243.png
# -----------------------------------------------------------------------------------------
# Image count                     :37
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190917115139.png
# -----------------------------------------------------------------------------------------
# Image count                     :38
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190917190855.png
# -----------------------------------------------------------------------------------------
# Image count                     :39
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190918055654.png
# -----------------------------------------------------------------------------------------
# Image count                     :40
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190918113340.png
# -----------------------------------------------------------------------------------------
# Image count                     :41
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190918194745.png
# -----------------------------------------------------------------------------------------
# Image count                     :42
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190919062142.png
# -----------------------------------------------------------------------------------------
# Image count                     :43
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190919185020.png
# -----------------------------------------------------------------------------------------
# Image count                     :44
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190920073541.png
# -----------------------------------------------------------------------------------------
# Image count                     :45
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190920115219.png
# -----------------------------------------------------------------------------------------
# Image count                     :46
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190920213847.png
# -----------------------------------------------------------------------------------------
# Image count                     :47
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190921075012.png
# -----------------------------------------------------------------------------------------
# Image count                     :48
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190921134919.png
# -----------------------------------------------------------------------------------------
# Image count                     :49
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190921211344.png
# -----------------------------------------------------------------------------------------
# Image count                     :50
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190922090725.png
# -----------------------------------------------------------------------------------------
# Image count                     :51
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190922140511.png
# -----------------------------------------------------------------------------------------
# Image count                     :52
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190922195810.png
# -----------------------------------------------------------------------------------------
# Image count                     :53
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190923070500.png
# -----------------------------------------------------------------------------------------
# Image count                     :54
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190923115957.png
# -----------------------------------------------------------------------------------------
# Image count                     :55
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190924055036.png
# -----------------------------------------------------------------------------------------
# Image count                     :56
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190925071822.png
# -----------------------------------------------------------------------------------------
# Image count                     :57
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190925115057.png
# -----------------------------------------------------------------------------------------
# Image count                     :58
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190925185617.png
# -----------------------------------------------------------------------------------------
# Image count                     :59
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190926062223.png
# -----------------------------------------------------------------------------------------
# Image count                     :60
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190926120710.png
# -----------------------------------------------------------------------------------------
# Image count                     :61
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190926205107.png
# -----------------------------------------------------------------------------------------
# Image count                     :62
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190927072509.png
# -----------------------------------------------------------------------------------------
# Image count                     :63
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190927120143.png
# -----------------------------------------------------------------------------------------
# Image count                     :64
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190927183614.png
# -----------------------------------------------------------------------------------------
# Image count                     :65
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190928081340.png
# -----------------------------------------------------------------------------------------
# Image count                     :66
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190929090339.png
# -----------------------------------------------------------------------------------------
# Image count                     :67
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190929122703.png
# -----------------------------------------------------------------------------------------
# Image count                     :68
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190929194655.png
# -----------------------------------------------------------------------------------------
# Image count                     :69
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190930073631.png
# -----------------------------------------------------------------------------------------
# Image count                     :70
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190930115757.png
# -----------------------------------------------------------------------------------------
# Image count                     :71
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20190930192909.png
# -----------------------------------------------------------------------------------------
# Image count                     :72
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20191001072056.png
# -----------------------------------------------------------------------------------------
# Image count                     :73
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20191001182226.png
# -----------------------------------------------------------------------------------------
# Image count                     :74
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20191002073237.png
# -----------------------------------------------------------------------------------------
# Image count                     :75
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20191002120226.png
# -----------------------------------------------------------------------------------------
# Image count                     :76
# Image in process is             :/content/drive/My Drive/Colab Notebooks/Inbody/data/1000072/20191002215321.png
# -----------------------------------------------------------------------------------------
# Extracting image features of the 76 input images is done

# %%
# display target_img
print("Target Image\n")
im = PIL.Image.open(target_img_path)
im = im.resize((224,224))
display(im)

# Calculate Cosine similarity between target_img and input_imgs
similarities = []
for i in range(0,input_count):
  similarity = tf.keras.losses.cosine_similarity(target_img, input_imgs[i][0])
  similarities.append([similarity,input_imgs[i][1]])

# display top 3 input_imgs which are the most similar with the target_img
similarities.sort()
print("\n\nThe 3 most similr images \n")
for s in range(1,4):
  im = PIL.Image.open(similarities[s][1])
  im = im.resize((224,224))
  display(im)
  print("Similarity: %.3f\n" %similarities[s][0])
# Out:
# Target Image
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F783E4C0AC8>
# The 3 most similr images
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F783E4C0AC8>
# Similarity: -0.939
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F783E4C0AC8>
# Similarity: -0.932
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F783E4C0AC8>
# Similarity: -0.930
